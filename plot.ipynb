# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df1 = pd.read_csv("data/csv/g0_actions_test.csv")
df2 = pd.read_csv("data/csv/g0_avg_test.csv")

# Add a column to differentiate between the files
df1['File'] = '0'
df2['File'] = '1'

# Concatenate the DataFrames
df = pd.concat([df1, df2])

# Apply a rolling window to smooth the data over 10 data points
window_size = 10
df['Rolling Min'] = df.groupby('File')['Value'].transform(lambda x: x.rolling(window=window_size, min_periods=1).min())
df['Rolling Max'] = df.groupby('File')['Value'].transform(lambda x: x.rolling(window=window_size, min_periods=1).max())
df['Smoothed Value'] = df.groupby('File')['Value'].transform(lambda x: x.rolling(window=window_size, min_periods=1).mean())

# Plotting using seaborn
fontsize = 20
fig, ax = plt.subplots(figsize=(12,6))

line1 = sns.lineplot(data=df.loc[df['File'] == '0'], x='Step', y='Smoothed Value', color = 'blue', style='File', dashes=False, label='Action', ax = ax)
ax.set_ylabel('Action', fontsize = fontsize)
ax.legend().remove()
ax.set_xlabel('')

ax2 = plt.twinx()
line2 = sns.lineplot(data=df.loc[df['File'] == '1'], x='Step', y='Smoothed Value', color = 'orange', style='File', dashes=False, label='Reward', ax = ax2)
ax2.set_ylabel('Reward', fontsize = fontsize)
ax2.legend().remove()

plt.grid(True)
plt.show()
# Out:
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df1 = pd.read_csv("data/csv/g10_actions_test.csv")
df2 = pd.read_csv("data/csv/g10_avg_test.csv")

# Add a column to differentiate between the files
df1['File'] = '0'
df2['File'] = '1'

# Concatenate the DataFrames
df = pd.concat([df1, df2])

# Apply a rolling window to smooth the data over 10 data points
window_size = 10
df['Rolling Min'] = df.groupby('File')['Value'].transform(lambda x: x.rolling(window=window_size, min_periods=1).min())
df['Rolling Max'] = df.groupby('File')['Value'].transform(lambda x: x.rolling(window=window_size, min_periods=1).max())
df['Smoothed Value'] = df.groupby('File')['Value'].transform(lambda x: x.rolling(window=window_size, min_periods=1).mean())

# Plotting using seaborn
fontsize = 20
fig, ax = plt.subplots(figsize=(12,6))

line1 = sns.lineplot(data=df.loc[df['File'] == '0'], x='Step', y='Smoothed Value', color = 'blue', style='File', dashes=False, label='Action', ax = ax)
ax.set_ylabel('Action', fontsize = fontsize)
ax.legend().remove()
ax.set_xlabel('')

ax2 = plt.twinx()
line2 = sns.lineplot(data=df.loc[df['File'] == '1'], x='Step', y='Smoothed Value', color = 'orange', style='File', dashes=False, label='Reward', ax = ax2)
ax2.set_ylabel('Reward', fontsize = fontsize)
ax2.legend().remove()

plt.grid(True)
plt.show()
# Out:
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df1 = pd.read_csv("data/csv/g0_actions_train.csv")
df2 = pd.read_csv("data/csv/g0_avg_train.csv")

# Add a column to differentiate between the files
df1['File'] = '0'
df2['File'] = '1'

# Concatenate the DataFrames
df = pd.concat([df1, df2]) # df3, df4

# Apply a rolling window to smooth the data over 10 data points
window_size = 100
df['Rolling Min'] = df.groupby('File')['Value'].transform(lambda x: x.rolling(window=window_size, min_periods=1).min())
df['Rolling Max'] = df.groupby('File')['Value'].transform(lambda x: x.rolling(window=window_size, min_periods=1).max())
df['Smoothed Value'] = df.groupby('File')['Value'].transform(lambda x: x.rolling(window=window_size, min_periods=1).mean())

# Plotting using seaborn
fig, ax = plt.subplots(figsize=(12,6))

line1 = sns.lineplot(data=df.loc[df['File'] == '0'], x='Step', y='Smoothed Value', color = 'blue', style='File', dashes=False, label='Action', ax = ax)
ax.set_ylabel('Action', fontsize = fontsize)
ax.legend().remove()
ax.set_xlabel('')

ax2 = plt.twinx()
line2 = sns.lineplot(data=df.loc[df['File'] == '1'], x='Step', y='Smoothed Value', color = 'orange', style='File', dashes=False, label='Reward', ax = ax2)
ax2.set_ylabel('Reward', fontsize = fontsize)
ax2.legend().remove()

plt.grid(True)
plt.show()
# Out:
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df1 = pd.read_csv("data/csv/g10_actions_train.csv")
df2 = pd.read_csv("data/csv/g10_avg_train.csv")

# Add a column to differentiate between the files
df1['File'] = '0'
df2['File'] = '1'

# Concatenate the DataFrames
df = pd.concat([df1, df2]) # df3, df4

# Apply a rolling window to smooth the data over 10 data points
window_size = 100
df['Rolling Min'] = df.groupby('File')['Value'].transform(lambda x: x.rolling(window=window_size, min_periods=1).min())
df['Rolling Max'] = df.groupby('File')['Value'].transform(lambda x: x.rolling(window=window_size, min_periods=1).max())
df['Smoothed Value'] = df.groupby('File')['Value'].transform(lambda x: x.rolling(window=window_size, min_periods=1).mean())

# Plotting using seaborn
fig, ax = plt.subplots(figsize=(12,6))

line1 = sns.lineplot(data=df.loc[df['File'] == '0'], x='Step', y='Smoothed Value', color = 'blue', style='File', dashes=False, label='Action', ax = ax)
ax.set_ylabel('Action', fontsize = fontsize)
ax.legend().remove()
ax.set_xlabel('')

ax2 = plt.twinx()
line2 = sns.lineplot(data=df.loc[df['File'] == '1'], x='Step', y='Smoothed Value', color = 'orange', style='File', dashes=False, label='Reward', ax = ax2)
ax2.set_ylabel('Reward', fontsize = fontsize)
ax2.legend().remove()

plt.grid(True)
plt.show()
# Out:
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/fabian/miniconda3/envs/neuro/lib/python3.12/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
